# %%
import pandas as pd
df = pd.read_csv(r"C:\dysk\CV — kopia\Naukaa\Python\Projects\API_Crypto_Project\Api_data\crypto_data.csv")
df
# Out:
#     Unnamed: 0     id          name symbol          slug  num_market_pairs  \
# 0            0      1       Bitcoin    BTC       bitcoin             12561
# 1            1   1027      Ethereum    ETH      ethereum             11567
# 2            2    825   Tether USDt   USDT        tether            171236
# 3            3     52           XRP    XRP           xrp              1798
# 4            4   1839           BNB    BNB           bnb              3134
# 5            5   3408          USDC   USDC      usd-coin             37475
# 6            6   5426        Solana    SOL        solana              1089
# 7            7   1958          TRON    TRX          tron              1299
# 8            8     74      Dogecoin   DOGE      dogecoin              1401
# 9            9   1831  Bitcoin Cash    BCH  bitcoin-cash              1137
# 10          10   2010       Cardano    ADA       cardano              1681
# 11          11  32196   Hyperliquid   HYPE   hyperliquid               238
# 12          12   3957  UNUS SED LEO    LEO  unus-sed-leo                67
# 13          13  29470   Ethena USDe   USDe   ethena-usde               295
# 14          14   1975     Chainlink   LINK     chainlink              2212
# 15           0      1       Bitcoin    BTC       bitcoin             12561
# 16           1   1027      Ethereum    ETH      ethereum             11567
# 17           2    825   Tether USDt   USDT        tether            171236
# 18           3     52           XRP    XRP           xrp              1798
# 19           4   1839           BNB    BNB           bnb              3134
# 20           5   3408          USDC   USDC      usd-coin             37475
# 21           6   5426        Solana    SOL        solana              1089
# 22           7   1958          TRON    TRX          tron              1299
# 23           8     74      Dogecoin   DOGE      dogecoin              1401
# 24           9   1831  Bitcoin Cash    BCH  bitcoin-cash              1137
# 25          10   2010       Cardano    ADA       cardano              1681
# 26          11  32196   Hyperliquid   HYPE   hyperliquid               238
# 27          12   3957  UNUS SED LEO    LEO  unus-sed-leo                67
# 28          13  29470   Ethena USDe   USDe   ethena-usde               295
# 29          14   1975     Chainlink   LINK     chainlink              2212
# 30           0      1       Bitcoin    BTC       bitcoin             12561
# 31           1   1027      Ethereum    ETH      ethereum             11567
# 32           2    825   Tether USDt   USDT        tether            171236
# 33           3     52           XRP    XRP           xrp              1798
# 34           4   1839           BNB    BNB           bnb              3134
# 35           5   3408          USDC   USDC      usd-coin             37475
# 36           6   5426        Solana    SOL        solana              1089
# 37           7   1958          TRON    TRX          tron              1299
# 38           8     74      Dogecoin   DOGE      dogecoin              1401
# 39           9   1831  Bitcoin Cash    BCH  bitcoin-cash              1137
# 40          10   2010       Cardano    ADA       cardano              1681
# 41          11  32196   Hyperliquid   HYPE   hyperliquid               238
# 42          12   3957  UNUS SED LEO    LEO  unus-sed-leo                67
# 43          13  29470   Ethena USDe   USDe   ethena-usde               295
# 44          14   1975     Chainlink   LINK     chainlink              2212
#
#                   date_added  \
# 0   2010-07-13T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2013-08-04T00:00:00.000Z
# 4   2017-07-25T00:00:00.000Z
# 5   2018-10-08T00:00:00.000Z
# 6   2020-04-10T00:00:00.000Z
# 7   2017-09-13T00:00:00.000Z
# 8   2013-12-15T00:00:00.000Z
# 9   2017-07-23T00:00:00.000Z
# 10  2017-10-01T00:00:00.000Z
# 11  2024-07-15T10:14:50.000Z
# 12  2019-05-21T00:00:00.000Z
# 13  2024-02-20T11:05:01.000Z
# 14  2017-09-20T00:00:00.000Z
# 15  2010-07-13T00:00:00.000Z
# 16  2015-08-07T00:00:00.000Z
# 17  2015-02-25T00:00:00.000Z
# 18  2013-08-04T00:00:00.000Z
# 19  2017-07-25T00:00:00.000Z
# 20  2018-10-08T00:00:00.000Z
# 21  2020-04-10T00:00:00.000Z
# 22  2017-09-13T00:00:00.000Z
# 23  2013-12-15T00:00:00.000Z
# 24  2017-07-23T00:00:00.000Z
# 25  2017-10-01T00:00:00.000Z
# 26  2024-07-15T10:14:50.000Z
# 27  2019-05-21T00:00:00.000Z
# 28  2024-02-20T11:05:01.000Z
# 29  2017-09-20T00:00:00.000Z
# 30  2010-07-13T00:00:00.000Z
# 31  2015-08-07T00:00:00.000Z
# 32  2015-02-25T00:00:00.000Z
# 33  2013-08-04T00:00:00.000Z
# 34  2017-07-25T00:00:00.000Z
# 35  2018-10-08T00:00:00.000Z
# 36  2020-04-10T00:00:00.000Z
# 37  2017-09-13T00:00:00.000Z
# 38  2013-12-15T00:00:00.000Z
# 39  2017-07-23T00:00:00.000Z
# 40  2017-10-01T00:00:00.000Z
# 41  2024-07-15T10:14:50.000Z
# 42  2019-05-21T00:00:00.000Z
# 43  2024-02-20T11:05:01.000Z
# 44  2017-09-20T00:00:00.000Z
#
#                                                  tags         max_supply  \
# 0   ['mineable', 'pow', 'sha-256', 'store-of-value...     21000000.00000
# 1   ['pos', 'smart-contracts', 'ethereum-ecosystem...                NaN
# 2   ['stablecoin', 'asset-backed-stablecoin', 'usd...                NaN
# 3   ['medium-of-exchange', 'enterprise-solutions',... 100000000000.00000
# 4   ['marketplace', 'centralized-exchange', 'payme...    136359286.38000
# 5   ['medium-of-exchange', 'stablecoin', 'asset-ba...                NaN
# 6   ['pos', 'platform', 'solana-ecosystem', 'cms-h...                NaN
# 7   ['media', 'payments', 'tron-ecosystem', 'layer...                NaN
# 8   ['mineable', 'pow', 'scrypt', 'medium-of-excha...                NaN
# 9   ['mineable', 'pow', 'sha-256', 'marketplace', ...     21000000.00000
# 10  ['dpos', 'pos', 'platform', 'research', 'smart...  45000000000.00000
# 11  ['decentralized-exchange-dex-token', 'defi', '...    961671487.86000
# 12  ['marketplace', 'centralized-exchange', 'disco...                NaN
# 13  ['stablecoin', 'asset-backed-stablecoin', 'bin...                NaN
# 14  ['platform', 'cosmos-ecosystem', 'defi', 'priv...   1000000000.00000
# 15  ['mineable', 'pow', 'sha-256', 'store-of-value...     21000000.00000
# 16  ['pos', 'smart-contracts', 'ethereum-ecosystem...                NaN
# 17  ['stablecoin', 'asset-backed-stablecoin', 'usd...                NaN
# 18  ['medium-of-exchange', 'enterprise-solutions',... 100000000000.00000
# 19  ['marketplace', 'centralized-exchange', 'payme...    136359286.38000
# 20  ['medium-of-exchange', 'stablecoin', 'asset-ba...                NaN
# 21  ['pos', 'platform', 'solana-ecosystem', 'cms-h...                NaN
# 22  ['media', 'payments', 'tron-ecosystem', 'layer...                NaN
# 23  ['mineable', 'pow', 'scrypt', 'medium-of-excha...                NaN
# 24  ['mineable', 'pow', 'sha-256', 'marketplace', ...     21000000.00000
# 25  ['dpos', 'pos', 'platform', 'research', 'smart...  45000000000.00000
# 26  ['decentralized-exchange-dex-token', 'defi', '...    961671487.86000
# 27  ['marketplace', 'centralized-exchange', 'disco...                NaN
# 28  ['stablecoin', 'asset-backed-stablecoin', 'bin...                NaN
# 29  ['platform', 'cosmos-ecosystem', 'defi', 'priv...   1000000000.00000
# 30  ['mineable', 'pow', 'sha-256', 'store-of-value...     21000000.00000
# 31  ['pos', 'smart-contracts', 'ethereum-ecosystem...                NaN
# 32  ['stablecoin', 'asset-backed-stablecoin', 'usd...                NaN
# 33  ['medium-of-exchange', 'enterprise-solutions',... 100000000000.00000
# 34  ['marketplace', 'centralized-exchange', 'payme...    136359286.38000
# 35  ['medium-of-exchange', 'stablecoin', 'asset-ba...                NaN
# 36  ['pos', 'platform', 'solana-ecosystem', 'cms-h...                NaN
# 37  ['media', 'payments', 'tron-ecosystem', 'layer...                NaN
# 38  ['mineable', 'pow', 'scrypt', 'medium-of-excha...                NaN
# 39  ['mineable', 'pow', 'sha-256', 'marketplace', ...     21000000.00000
# 40  ['dpos', 'pos', 'platform', 'research', 'smart...  45000000000.00000
# 41  ['decentralized-exchange-dex-token', 'defi', '...    961671487.86000
# 42  ['marketplace', 'centralized-exchange', 'disco...                NaN
# 43  ['stablecoin', 'asset-backed-stablecoin', 'bin...                NaN
# 44  ['platform', 'cosmos-ecosystem', 'defi', 'priv...   1000000000.00000
#
#     circulating_supply  ...  quote.USD.market_cap_dominance  \
# 0       19989828.00000  ...                        58.22660
# 1      120692457.90000  ...                        10.23480
# 2   183755310128.52243  ...                         7.75690
# 3    60917315351.00000  ...                         3.94020
# 4      136359285.10000  ...                         3.57680
# 5    73578985943.34981  ...                         3.10790
# 6      567957580.88020  ...                         2.09240
# 7    94724698536.48190  ...                         1.12240
# 8   168751803126.57907  ...                         0.77220
# 9       19995162.50000  ...                         0.47080
# 10   36066145196.64397  ...                         0.43460
# 11     259280977.98690  ...                         0.33840
# 12     921353012.90000  ...                         0.32820
# 13    6304778696.79133  ...                         0.26600
# 14     708099970.45259  ...                         0.26510
# 15      19989828.00000  ...                        58.19390
# 16     120692457.90000  ...                        10.23030
# 17  183755310128.52243  ...                         7.75780
# 18   60917315351.00000  ...                         3.94070
# 19     136359285.10000  ...                         3.57720
# 20   73578985943.34981  ...                         3.10760
# 21     567957580.88020  ...                         2.09230
# 22   94724698536.48190  ...                         1.12250
# 23  168751803126.57907  ...                         0.77220
# 24      19995162.50000  ...                         0.47080
# 25   36066145196.64397  ...                         0.43460
# 26     259280977.98690  ...                         0.33840
# 27     921353012.90000  ...                         0.32820
# 28    6304778696.79133  ...                         0.26600
# 29     708099970.45259  ...                         0.26510
# 30      19989828.00000  ...                        58.22820
# 31     120692457.90000  ...                        10.23540
# 32  183755310128.52243  ...                         7.75770
# 33   60917315351.00000  ...                         3.94030
# 34     136359285.10000  ...                         3.57690
# 35   73578985943.34981  ...                         3.10780
# 36     567957580.88020  ...                         2.09270
# 37   94724698536.48190  ...                         1.12250
# 38  168751803126.57907  ...                         0.77230
# 39      19995162.50000  ...                         0.47080
# 40   36066145196.64397  ...                         0.43460
# 41     259280977.98690  ...                         0.33850
# 42     921353012.90000  ...                         0.32820
# 43    6304778696.79133  ...                         0.26600
# 44     708099970.45259  ...                         0.26500
#
#     quote.USD.fully_diluted_market_cap  quote.USD.tvl  \
# 0                  1448237755943.13989            NaN
# 1                   242319683452.66000            NaN
# 2                   187860335589.76999            NaN
# 3                   153138533463.19000            NaN
# 4                    84684683857.75000            NaN
# 5                    73583253801.14000            NaN
# 6                    54113671195.78000            NaN
# 7                    26574149424.47000            NaN
# 8                    18281665663.04000            NaN
# 9                    11707695817.88000            NaN
# 10                   12838687428.61000            NaN
# 11                   29718169569.77000            NaN
# 12                    8309555231.92000            NaN
# 13                    6298055666.30000            NaN
# 14                    8862643329.51000            NaN
# 15                 1447425888552.16992            NaN
# 16                  242213796946.14999            NaN
# 17                  187880910341.10999            NaN
# 18                  153156783314.70999            NaN
# 19                   84693181860.99001            NaN
# 20                   73575621701.00999            NaN
# 21                   54111454305.83000            NaN
# 22                   26576093438.18000            NaN
# 23                   18281665663.04000            NaN
# 24                   11706775253.00000            NaN
# 25                   12839069595.40000            NaN
# 26                   29718169569.77000            NaN
# 27                    8309432247.03000            NaN
# 28                    6298032235.21000            NaN
# 29                    8862691162.47000            NaN
# 30                 1448279403391.61011            NaN
# 31                  242334576039.14999            NaN
# 32                  187878026492.45999            NaN
# 33                  153141761689.04999            NaN
# 34                   84687353738.83000            NaN
# 35                   73579596740.45000            NaN
# 36                   54121048428.33000            NaN
# 37                   26575844293.35000            NaN
# 38                   18285070606.34000            NaN
# 39                   11706616796.26000            NaN
# 40                   12838369318.60000            NaN
# 41                   29723948617.87000            NaN
# 42                    8309519676.02000            NaN
# 43                    6298032235.21000            NaN
# 44                    8862200752.26000            NaN
#
#       quote.USD.last_updated  platform.id  platform.name  platform.symbol  \
# 0   2026-02-15T15:24:00.000Z          NaN            NaN              NaN
# 1   2026-02-15T15:24:00.000Z          NaN            NaN              NaN
# 2   2026-02-15T15:24:00.000Z   1027.00000       Ethereum              ETH
# 3   2026-02-15T15:25:00.000Z          NaN            NaN              NaN
# 4   2026-02-15T15:25:00.000Z          NaN            NaN              NaN
# 5   2026-02-15T15:24:00.000Z   1027.00000       Ethereum              ETH
# 6   2026-02-15T15:24:00.000Z          NaN            NaN              NaN
# 7   2026-02-15T15:25:00.000Z          NaN            NaN              NaN
# 8   2026-02-15T15:25:00.000Z          NaN            NaN              NaN
# 9   2026-02-15T15:24:00.000Z          NaN            NaN              NaN
# 10  2026-02-15T15:25:00.000Z          NaN            NaN              NaN
# 11  2026-02-15T15:25:00.000Z  32196.00000    Hyperliquid             HYPE
# 12  2026-02-15T15:25:00.000Z   1027.00000       Ethereum              ETH
# 13  2026-02-15T15:25:00.000Z   1027.00000       Ethereum              ETH
# 14  2026-02-15T15:25:00.000Z   1027.00000       Ethereum              ETH
# 15  2026-02-15T15:25:00.000Z          NaN            NaN              NaN
# 16  2026-02-15T15:25:00.000Z          NaN            NaN              NaN
# 17  2026-02-15T15:25:00.000Z   1027.00000       Ethereum              ETH
# 18  2026-02-15T15:26:00.000Z          NaN            NaN              NaN
# 19  2026-02-15T15:26:00.000Z          NaN            NaN              NaN
# 20  2026-02-15T15:25:00.000Z   1027.00000       Ethereum              ETH
# 21  2026-02-15T15:25:00.000Z          NaN            NaN              NaN
# 22  2026-02-15T15:26:00.000Z          NaN            NaN              NaN
# 23  2026-02-15T15:25:00.000Z          NaN            NaN              NaN
# 24  2026-02-15T15:25:00.000Z          NaN            NaN              NaN
# 25  2026-02-15T15:26:00.000Z          NaN            NaN              NaN
# 26  2026-02-15T15:25:00.000Z  32196.00000    Hyperliquid             HYPE
# 27  2026-02-15T15:26:00.000Z   1027.00000       Ethereum              ETH
# 28  2026-02-15T15:26:00.000Z   1027.00000       Ethereum              ETH
# 29  2026-02-15T15:26:00.000Z   1027.00000       Ethereum              ETH
# 30  2026-02-15T15:26:00.000Z          NaN            NaN              NaN
# 31  2026-02-15T15:26:00.000Z          NaN            NaN              NaN
# 32  2026-02-15T15:26:00.000Z   1027.00000       Ethereum              ETH
# 33  2026-02-15T15:27:00.000Z          NaN            NaN              NaN
# 34  2026-02-15T15:27:00.000Z          NaN            NaN              NaN
# 35  2026-02-15T15:26:00.000Z   1027.00000       Ethereum              ETH
# 36  2026-02-15T15:26:00.000Z          NaN            NaN              NaN
# 37  2026-02-15T15:27:00.000Z          NaN            NaN              NaN
# 38  2026-02-15T15:26:00.000Z          NaN            NaN              NaN
# 39  2026-02-15T15:26:00.000Z          NaN            NaN              NaN
# 40  2026-02-15T15:27:00.000Z          NaN            NaN              NaN
# 41  2026-02-15T15:27:00.000Z  32196.00000    Hyperliquid             HYPE
# 42  2026-02-15T15:27:00.000Z   1027.00000       Ethereum              ETH
# 43  2026-02-15T15:26:00.000Z   1027.00000       Ethereum              ETH
# 44  2026-02-15T15:27:00.000Z   1027.00000       Ethereum              ETH
#
#     platform.slug                      platform.token_address  \
# 0             NaN                                         NaN
# 1             NaN                                         NaN
# 2        ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3             NaN                                         NaN
# 4             NaN                                         NaN
# 5        ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 6             NaN                                         NaN
# 7             NaN                                         NaN
# 8             NaN                                         NaN
# 9             NaN                                         NaN
# 10            NaN                                         NaN
# 11    hyperliquid          0x0d01dc56dcaaca66ad901c959b4011ec
# 12       ethereum  0x2af5d2ad76741191d15dfe7bf6ac92d4bd912ca3
# 13       ethereum  0x4c9edd5852cd905f086c759e8383e09bff1e68b3
# 14       ethereum  0x514910771af9ca656af840dff83e8264ecf986ca
# 15            NaN                                         NaN
# 16            NaN                                         NaN
# 17       ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 18            NaN                                         NaN
# 19            NaN                                         NaN
# 20       ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 21            NaN                                         NaN
# 22            NaN                                         NaN
# 23            NaN                                         NaN
# 24            NaN                                         NaN
# 25            NaN                                         NaN
# 26    hyperliquid          0x0d01dc56dcaaca66ad901c959b4011ec
# 27       ethereum  0x2af5d2ad76741191d15dfe7bf6ac92d4bd912ca3
# 28       ethereum  0x4c9edd5852cd905f086c759e8383e09bff1e68b3
# 29       ethereum  0x514910771af9ca656af840dff83e8264ecf986ca
# 30            NaN                                         NaN
# 31            NaN                                         NaN
# 32       ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 33            NaN                                         NaN
# 34            NaN                                         NaN
# 35       ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 36            NaN                                         NaN
# 37            NaN                                         NaN
# 38            NaN                                         NaN
# 39            NaN                                         NaN
# 40            NaN                                         NaN
# 41    hyperliquid          0x0d01dc56dcaaca66ad901c959b4011ec
# 42       ethereum  0x2af5d2ad76741191d15dfe7bf6ac92d4bd912ca3
# 43       ethereum  0x4c9edd5852cd905f086c759e8383e09bff1e68b3
# 44       ethereum  0x514910771af9ca656af840dff83e8264ecf986ca
#
#                      timestamp
# 0   2026-02-15 16:26:04.766852
# 1   2026-02-15 16:26:04.766852
# 2   2026-02-15 16:26:04.766852
# 3   2026-02-15 16:26:04.766852
# 4   2026-02-15 16:26:04.766852
# 5   2026-02-15 16:26:04.766852
# 6   2026-02-15 16:26:04.766852
# 7   2026-02-15 16:26:04.766852
# 8   2026-02-15 16:26:04.766852
# 9   2026-02-15 16:26:04.766852
# 10  2026-02-15 16:26:04.766852
# 11  2026-02-15 16:26:04.766852
# 12  2026-02-15 16:26:04.766852
# 13  2026-02-15 16:26:04.766852
# 14  2026-02-15 16:26:04.766852
# 15  2026-02-15 16:27:05.135207
# 16  2026-02-15 16:27:05.135207
# 17  2026-02-15 16:27:05.135207
# 18  2026-02-15 16:27:05.135207
# 19  2026-02-15 16:27:05.135207
# 20  2026-02-15 16:27:05.135207
# 21  2026-02-15 16:27:05.135207
# 22  2026-02-15 16:27:05.135207
# 23  2026-02-15 16:27:05.135207
# 24  2026-02-15 16:27:05.135207
# 25  2026-02-15 16:27:05.135207
# 26  2026-02-15 16:27:05.135207
# 27  2026-02-15 16:27:05.135207
# 28  2026-02-15 16:27:05.135207
# 29  2026-02-15 16:27:05.135207
# 30  2026-02-15 16:28:05.507406
# 31  2026-02-15 16:28:05.507406
# 32  2026-02-15 16:28:05.507406
# 33  2026-02-15 16:28:05.507406
# 34  2026-02-15 16:28:05.507406
# 35  2026-02-15 16:28:05.507406
# 36  2026-02-15 16:28:05.507406
# 37  2026-02-15 16:28:05.507406
# 38  2026-02-15 16:28:05.507406
# 39  2026-02-15 16:28:05.507406
# 40  2026-02-15 16:28:05.507406
# 41  2026-02-15 16:28:05.507406
# 42  2026-02-15 16:28:05.507406
# 43  2026-02-15 16:28:05.507406
# 44  2026-02-15 16:28:05.507406
#
# [45 rows x 39 columns]

# %%
#displaying all columns and setting the float format to 5 decimal places
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
df2 = df
df2
# Out:
#     Unnamed: 0     id          name symbol          slug  num_market_pairs  \
# 0            0      1       Bitcoin    BTC       bitcoin             12561
# 1            1   1027      Ethereum    ETH      ethereum             11567
# 2            2    825   Tether USDt   USDT        tether            171236
# 3            3     52           XRP    XRP           xrp              1798
# 4            4   1839           BNB    BNB           bnb              3134
# 5            5   3408          USDC   USDC      usd-coin             37475
# 6            6   5426        Solana    SOL        solana              1089
# 7            7   1958          TRON    TRX          tron              1299
# 8            8     74      Dogecoin   DOGE      dogecoin              1401
# 9            9   1831  Bitcoin Cash    BCH  bitcoin-cash              1137
# 10          10   2010       Cardano    ADA       cardano              1681
# 11          11  32196   Hyperliquid   HYPE   hyperliquid               238
# 12          12   3957  UNUS SED LEO    LEO  unus-sed-leo                67
# 13          13  29470   Ethena USDe   USDe   ethena-usde               295
# 14          14   1975     Chainlink   LINK     chainlink              2212
# 15           0      1       Bitcoin    BTC       bitcoin             12561
# 16           1   1027      Ethereum    ETH      ethereum             11567
# 17           2    825   Tether USDt   USDT        tether            171236
# 18           3     52           XRP    XRP           xrp              1798
# 19           4   1839           BNB    BNB           bnb              3134
# 20           5   3408          USDC   USDC      usd-coin             37475
# 21           6   5426        Solana    SOL        solana              1089
# 22           7   1958          TRON    TRX          tron              1299
# 23           8     74      Dogecoin   DOGE      dogecoin              1401
# 24           9   1831  Bitcoin Cash    BCH  bitcoin-cash              1137
# 25          10   2010       Cardano    ADA       cardano              1681
# 26          11  32196   Hyperliquid   HYPE   hyperliquid               238
# 27          12   3957  UNUS SED LEO    LEO  unus-sed-leo                67
# 28          13  29470   Ethena USDe   USDe   ethena-usde               295
# 29          14   1975     Chainlink   LINK     chainlink              2212
# 30           0      1       Bitcoin    BTC       bitcoin             12561
# 31           1   1027      Ethereum    ETH      ethereum             11567
# 32           2    825   Tether USDt   USDT        tether            171236
# 33           3     52           XRP    XRP           xrp              1798
# 34           4   1839           BNB    BNB           bnb              3134
# 35           5   3408          USDC   USDC      usd-coin             37475
# 36           6   5426        Solana    SOL        solana              1089
# 37           7   1958          TRON    TRX          tron              1299
# 38           8     74      Dogecoin   DOGE      dogecoin              1401
# 39           9   1831  Bitcoin Cash    BCH  bitcoin-cash              1137
# 40          10   2010       Cardano    ADA       cardano              1681
# 41          11  32196   Hyperliquid   HYPE   hyperliquid               238
# 42          12   3957  UNUS SED LEO    LEO  unus-sed-leo                67
# 43          13  29470   Ethena USDe   USDe   ethena-usde               295
# 44          14   1975     Chainlink   LINK     chainlink              2212
#
#                   date_added  \
# 0   2010-07-13T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2013-08-04T00:00:00.000Z
# 4   2017-07-25T00:00:00.000Z
# 5   2018-10-08T00:00:00.000Z
# 6   2020-04-10T00:00:00.000Z
# 7   2017-09-13T00:00:00.000Z
# 8   2013-12-15T00:00:00.000Z
# 9   2017-07-23T00:00:00.000Z
# 10  2017-10-01T00:00:00.000Z
# 11  2024-07-15T10:14:50.000Z
# 12  2019-05-21T00:00:00.000Z
# 13  2024-02-20T11:05:01.000Z
# 14  2017-09-20T00:00:00.000Z
# 15  2010-07-13T00:00:00.000Z
# 16  2015-08-07T00:00:00.000Z
# 17  2015-02-25T00:00:00.000Z
# 18  2013-08-04T00:00:00.000Z
# 19  2017-07-25T00:00:00.000Z
# 20  2018-10-08T00:00:00.000Z
# 21  2020-04-10T00:00:00.000Z
# 22  2017-09-13T00:00:00.000Z
# 23  2013-12-15T00:00:00.000Z
# 24  2017-07-23T00:00:00.000Z
# 25  2017-10-01T00:00:00.000Z
# 26  2024-07-15T10:14:50.000Z
# 27  2019-05-21T00:00:00.000Z
# 28  2024-02-20T11:05:01.000Z
# 29  2017-09-20T00:00:00.000Z
# 30  2010-07-13T00:00:00.000Z
# 31  2015-08-07T00:00:00.000Z
# 32  2015-02-25T00:00:00.000Z
# 33  2013-08-04T00:00:00.000Z
# 34  2017-07-25T00:00:00.000Z
# 35  2018-10-08T00:00:00.000Z
# 36  2020-04-10T00:00:00.000Z
# 37  2017-09-13T00:00:00.000Z
# 38  2013-12-15T00:00:00.000Z
# 39  2017-07-23T00:00:00.000Z
# 40  2017-10-01T00:00:00.000Z
# 41  2024-07-15T10:14:50.000Z
# 42  2019-05-21T00:00:00.000Z
# 43  2024-02-20T11:05:01.000Z
# 44  2017-09-20T00:00:00.000Z
#
#                                                  tags         max_supply  \
# 0   ['mineable', 'pow', 'sha-256', 'store-of-value...     21000000.00000
# 1   ['pos', 'smart-contracts', 'ethereum-ecosystem...                NaN
# 2   ['stablecoin', 'asset-backed-stablecoin', 'usd...                NaN
# 3   ['medium-of-exchange', 'enterprise-solutions',... 100000000000.00000
# 4   ['marketplace', 'centralized-exchange', 'payme...    136359286.38000
# 5   ['medium-of-exchange', 'stablecoin', 'asset-ba...                NaN
# 6   ['pos', 'platform', 'solana-ecosystem', 'cms-h...                NaN
# 7   ['media', 'payments', 'tron-ecosystem', 'layer...                NaN
# 8   ['mineable', 'pow', 'scrypt', 'medium-of-excha...                NaN
# 9   ['mineable', 'pow', 'sha-256', 'marketplace', ...     21000000.00000
# 10  ['dpos', 'pos', 'platform', 'research', 'smart...  45000000000.00000
# 11  ['decentralized-exchange-dex-token', 'defi', '...    961671487.86000
# 12  ['marketplace', 'centralized-exchange', 'disco...                NaN
# 13  ['stablecoin', 'asset-backed-stablecoin', 'bin...                NaN
# 14  ['platform', 'cosmos-ecosystem', 'defi', 'priv...   1000000000.00000
# 15  ['mineable', 'pow', 'sha-256', 'store-of-value...     21000000.00000
# 16  ['pos', 'smart-contracts', 'ethereum-ecosystem...                NaN
# 17  ['stablecoin', 'asset-backed-stablecoin', 'usd...                NaN
# 18  ['medium-of-exchange', 'enterprise-solutions',... 100000000000.00000
# 19  ['marketplace', 'centralized-exchange', 'payme...    136359286.38000
# 20  ['medium-of-exchange', 'stablecoin', 'asset-ba...                NaN
# 21  ['pos', 'platform', 'solana-ecosystem', 'cms-h...                NaN
# 22  ['media', 'payments', 'tron-ecosystem', 'layer...                NaN
# 23  ['mineable', 'pow', 'scrypt', 'medium-of-excha...                NaN
# 24  ['mineable', 'pow', 'sha-256', 'marketplace', ...     21000000.00000
# 25  ['dpos', 'pos', 'platform', 'research', 'smart...  45000000000.00000
# 26  ['decentralized-exchange-dex-token', 'defi', '...    961671487.86000
# 27  ['marketplace', 'centralized-exchange', 'disco...                NaN
# 28  ['stablecoin', 'asset-backed-stablecoin', 'bin...                NaN
# 29  ['platform', 'cosmos-ecosystem', 'defi', 'priv...   1000000000.00000
# 30  ['mineable', 'pow', 'sha-256', 'store-of-value...     21000000.00000
# 31  ['pos', 'smart-contracts', 'ethereum-ecosystem...                NaN
# 32  ['stablecoin', 'asset-backed-stablecoin', 'usd...                NaN
# 33  ['medium-of-exchange', 'enterprise-solutions',... 100000000000.00000
# 34  ['marketplace', 'centralized-exchange', 'payme...    136359286.38000
# 35  ['medium-of-exchange', 'stablecoin', 'asset-ba...                NaN
# 36  ['pos', 'platform', 'solana-ecosystem', 'cms-h...                NaN
# 37  ['media', 'payments', 'tron-ecosystem', 'layer...                NaN
# 38  ['mineable', 'pow', 'scrypt', 'medium-of-excha...                NaN
# 39  ['mineable', 'pow', 'sha-256', 'marketplace', ...     21000000.00000
# 40  ['dpos', 'pos', 'platform', 'research', 'smart...  45000000000.00000
# 41  ['decentralized-exchange-dex-token', 'defi', '...    961671487.86000
# 42  ['marketplace', 'centralized-exchange', 'disco...                NaN
# 43  ['stablecoin', 'asset-backed-stablecoin', 'bin...                NaN
# 44  ['platform', 'cosmos-ecosystem', 'defi', 'priv...   1000000000.00000
#
#     circulating_supply  ...  quote.USD.market_cap_dominance  \
# 0       19989828.00000  ...                        58.22660
# 1      120692457.90000  ...                        10.23480
# 2   183755310128.52243  ...                         7.75690
# 3    60917315351.00000  ...                         3.94020
# 4      136359285.10000  ...                         3.57680
# 5    73578985943.34981  ...                         3.10790
# 6      567957580.88020  ...                         2.09240
# 7    94724698536.48190  ...                         1.12240
# 8   168751803126.57907  ...                         0.77220
# 9       19995162.50000  ...                         0.47080
# 10   36066145196.64397  ...                         0.43460
# 11     259280977.98690  ...                         0.33840
# 12     921353012.90000  ...                         0.32820
# 13    6304778696.79133  ...                         0.26600
# 14     708099970.45259  ...                         0.26510
# 15      19989828.00000  ...                        58.19390
# 16     120692457.90000  ...                        10.23030
# 17  183755310128.52243  ...                         7.75780
# 18   60917315351.00000  ...                         3.94070
# 19     136359285.10000  ...                         3.57720
# 20   73578985943.34981  ...                         3.10760
# 21     567957580.88020  ...                         2.09230
# 22   94724698536.48190  ...                         1.12250
# 23  168751803126.57907  ...                         0.77220
# 24      19995162.50000  ...                         0.47080
# 25   36066145196.64397  ...                         0.43460
# 26     259280977.98690  ...                         0.33840
# 27     921353012.90000  ...                         0.32820
# 28    6304778696.79133  ...                         0.26600
# 29     708099970.45259  ...                         0.26510
# 30      19989828.00000  ...                        58.22820
# 31     120692457.90000  ...                        10.23540
# 32  183755310128.52243  ...                         7.75770
# 33   60917315351.00000  ...                         3.94030
# 34     136359285.10000  ...                         3.57690
# 35   73578985943.34981  ...                         3.10780
# 36     567957580.88020  ...                         2.09270
# 37   94724698536.48190  ...                         1.12250
# 38  168751803126.57907  ...                         0.77230
# 39      19995162.50000  ...                         0.47080
# 40   36066145196.64397  ...                         0.43460
# 41     259280977.98690  ...                         0.33850
# 42     921353012.90000  ...                         0.32820
# 43    6304778696.79133  ...                         0.26600
# 44     708099970.45259  ...                         0.26500
#
#     quote.USD.fully_diluted_market_cap  quote.USD.tvl  \
# 0                  1448237755943.13989            NaN
# 1                   242319683452.66000            NaN
# 2                   187860335589.76999            NaN
# 3                   153138533463.19000            NaN
# 4                    84684683857.75000            NaN
# 5                    73583253801.14000            NaN
# 6                    54113671195.78000            NaN
# 7                    26574149424.47000            NaN
# 8                    18281665663.04000            NaN
# 9                    11707695817.88000            NaN
# 10                   12838687428.61000            NaN
# 11                   29718169569.77000            NaN
# 12                    8309555231.92000            NaN
# 13                    6298055666.30000            NaN
# 14                    8862643329.51000            NaN
# 15                 1447425888552.16992            NaN
# 16                  242213796946.14999            NaN
# 17                  187880910341.10999            NaN
# 18                  153156783314.70999            NaN
# 19                   84693181860.99001            NaN
# 20                   73575621701.00999            NaN
# 21                   54111454305.83000            NaN
# 22                   26576093438.18000            NaN
# 23                   18281665663.04000            NaN
# 24                   11706775253.00000            NaN
# 25                   12839069595.40000            NaN
# 26                   29718169569.77000            NaN
# 27                    8309432247.03000            NaN
# 28                    6298032235.21000            NaN
# 29                    8862691162.47000            NaN
# 30                 1448279403391.61011            NaN
# 31                  242334576039.14999            NaN
# 32                  187878026492.45999            NaN
# 33                  153141761689.04999            NaN
# 34                   84687353738.83000            NaN
# 35                   73579596740.45000            NaN
# 36                   54121048428.33000            NaN
# 37                   26575844293.35000            NaN
# 38                   18285070606.34000            NaN
# 39                   11706616796.26000            NaN
# 40                   12838369318.60000            NaN
# 41                   29723948617.87000            NaN
# 42                    8309519676.02000            NaN
# 43                    6298032235.21000            NaN
# 44                    8862200752.26000            NaN
#
#       quote.USD.last_updated  platform.id  platform.name  platform.symbol  \
# 0   2026-02-15T15:24:00.000Z          NaN            NaN              NaN
# 1   2026-02-15T15:24:00.000Z          NaN            NaN              NaN
# 2   2026-02-15T15:24:00.000Z   1027.00000       Ethereum              ETH
# 3   2026-02-15T15:25:00.000Z          NaN            NaN              NaN
# 4   2026-02-15T15:25:00.000Z          NaN            NaN              NaN
# 5   2026-02-15T15:24:00.000Z   1027.00000       Ethereum              ETH
# 6   2026-02-15T15:24:00.000Z          NaN            NaN              NaN
# 7   2026-02-15T15:25:00.000Z          NaN            NaN              NaN
# 8   2026-02-15T15:25:00.000Z          NaN            NaN              NaN
# 9   2026-02-15T15:24:00.000Z          NaN            NaN              NaN
# 10  2026-02-15T15:25:00.000Z          NaN            NaN              NaN
# 11  2026-02-15T15:25:00.000Z  32196.00000    Hyperliquid             HYPE
# 12  2026-02-15T15:25:00.000Z   1027.00000       Ethereum              ETH
# 13  2026-02-15T15:25:00.000Z   1027.00000       Ethereum              ETH
# 14  2026-02-15T15:25:00.000Z   1027.00000       Ethereum              ETH
# 15  2026-02-15T15:25:00.000Z          NaN            NaN              NaN
# 16  2026-02-15T15:25:00.000Z          NaN            NaN              NaN
# 17  2026-02-15T15:25:00.000Z   1027.00000       Ethereum              ETH
# 18  2026-02-15T15:26:00.000Z          NaN            NaN              NaN
# 19  2026-02-15T15:26:00.000Z          NaN            NaN              NaN
# 20  2026-02-15T15:25:00.000Z   1027.00000       Ethereum              ETH
# 21  2026-02-15T15:25:00.000Z          NaN            NaN              NaN
# 22  2026-02-15T15:26:00.000Z          NaN            NaN              NaN
# 23  2026-02-15T15:25:00.000Z          NaN            NaN              NaN
# 24  2026-02-15T15:25:00.000Z          NaN            NaN              NaN
# 25  2026-02-15T15:26:00.000Z          NaN            NaN              NaN
# 26  2026-02-15T15:25:00.000Z  32196.00000    Hyperliquid             HYPE
# 27  2026-02-15T15:26:00.000Z   1027.00000       Ethereum              ETH
# 28  2026-02-15T15:26:00.000Z   1027.00000       Ethereum              ETH
# 29  2026-02-15T15:26:00.000Z   1027.00000       Ethereum              ETH
# 30  2026-02-15T15:26:00.000Z          NaN            NaN              NaN
# 31  2026-02-15T15:26:00.000Z          NaN            NaN              NaN
# 32  2026-02-15T15:26:00.000Z   1027.00000       Ethereum              ETH
# 33  2026-02-15T15:27:00.000Z          NaN            NaN              NaN
# 34  2026-02-15T15:27:00.000Z          NaN            NaN              NaN
# 35  2026-02-15T15:26:00.000Z   1027.00000       Ethereum              ETH
# 36  2026-02-15T15:26:00.000Z          NaN            NaN              NaN
# 37  2026-02-15T15:27:00.000Z          NaN            NaN              NaN
# 38  2026-02-15T15:26:00.000Z          NaN            NaN              NaN
# 39  2026-02-15T15:26:00.000Z          NaN            NaN              NaN
# 40  2026-02-15T15:27:00.000Z          NaN            NaN              NaN
# 41  2026-02-15T15:27:00.000Z  32196.00000    Hyperliquid             HYPE
# 42  2026-02-15T15:27:00.000Z   1027.00000       Ethereum              ETH
# 43  2026-02-15T15:26:00.000Z   1027.00000       Ethereum              ETH
# 44  2026-02-15T15:27:00.000Z   1027.00000       Ethereum              ETH
#
#     platform.slug                      platform.token_address  \
# 0             NaN                                         NaN
# 1             NaN                                         NaN
# 2        ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3             NaN                                         NaN
# 4             NaN                                         NaN
# 5        ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 6             NaN                                         NaN
# 7             NaN                                         NaN
# 8             NaN                                         NaN
# 9             NaN                                         NaN
# 10            NaN                                         NaN
# 11    hyperliquid          0x0d01dc56dcaaca66ad901c959b4011ec
# 12       ethereum  0x2af5d2ad76741191d15dfe7bf6ac92d4bd912ca3
# 13       ethereum  0x4c9edd5852cd905f086c759e8383e09bff1e68b3
# 14       ethereum  0x514910771af9ca656af840dff83e8264ecf986ca
# 15            NaN                                         NaN
# 16            NaN                                         NaN
# 17       ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 18            NaN                                         NaN
# 19            NaN                                         NaN
# 20       ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 21            NaN                                         NaN
# 22            NaN                                         NaN
# 23            NaN                                         NaN
# 24            NaN                                         NaN
# 25            NaN                                         NaN
# 26    hyperliquid          0x0d01dc56dcaaca66ad901c959b4011ec
# 27       ethereum  0x2af5d2ad76741191d15dfe7bf6ac92d4bd912ca3
# 28       ethereum  0x4c9edd5852cd905f086c759e8383e09bff1e68b3
# 29       ethereum  0x514910771af9ca656af840dff83e8264ecf986ca
# 30            NaN                                         NaN
# 31            NaN                                         NaN
# 32       ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 33            NaN                                         NaN
# 34            NaN                                         NaN
# 35       ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 36            NaN                                         NaN
# 37            NaN                                         NaN
# 38            NaN                                         NaN
# 39            NaN                                         NaN
# 40            NaN                                         NaN
# 41    hyperliquid          0x0d01dc56dcaaca66ad901c959b4011ec
# 42       ethereum  0x2af5d2ad76741191d15dfe7bf6ac92d4bd912ca3
# 43       ethereum  0x4c9edd5852cd905f086c759e8383e09bff1e68b3
# 44       ethereum  0x514910771af9ca656af840dff83e8264ecf986ca
#
#                      timestamp
# 0   2026-02-15 16:26:04.766852
# 1   2026-02-15 16:26:04.766852
# 2   2026-02-15 16:26:04.766852
# 3   2026-02-15 16:26:04.766852
# 4   2026-02-15 16:26:04.766852
# 5   2026-02-15 16:26:04.766852
# 6   2026-02-15 16:26:04.766852
# 7   2026-02-15 16:26:04.766852
# 8   2026-02-15 16:26:04.766852
# 9   2026-02-15 16:26:04.766852
# 10  2026-02-15 16:26:04.766852
# 11  2026-02-15 16:26:04.766852
# 12  2026-02-15 16:26:04.766852
# 13  2026-02-15 16:26:04.766852
# 14  2026-02-15 16:26:04.766852
# 15  2026-02-15 16:27:05.135207
# 16  2026-02-15 16:27:05.135207
# 17  2026-02-15 16:27:05.135207
# 18  2026-02-15 16:27:05.135207
# 19  2026-02-15 16:27:05.135207
# 20  2026-02-15 16:27:05.135207
# 21  2026-02-15 16:27:05.135207
# 22  2026-02-15 16:27:05.135207
# 23  2026-02-15 16:27:05.135207
# 24  2026-02-15 16:27:05.135207
# 25  2026-02-15 16:27:05.135207
# 26  2026-02-15 16:27:05.135207
# 27  2026-02-15 16:27:05.135207
# 28  2026-02-15 16:27:05.135207
# 29  2026-02-15 16:27:05.135207
# 30  2026-02-15 16:28:05.507406
# 31  2026-02-15 16:28:05.507406
# 32  2026-02-15 16:28:05.507406
# 33  2026-02-15 16:28:05.507406
# 34  2026-02-15 16:28:05.507406
# 35  2026-02-15 16:28:05.507406
# 36  2026-02-15 16:28:05.507406
# 37  2026-02-15 16:28:05.507406
# 38  2026-02-15 16:28:05.507406
# 39  2026-02-15 16:28:05.507406
# 40  2026-02-15 16:28:05.507406
# 41  2026-02-15 16:28:05.507406
# 42  2026-02-15 16:28:05.507406
# 43  2026-02-15 16:28:05.507406
# 44  2026-02-15 16:28:05.507406
#
# [45 rows x 39 columns]

# %%
# Now let's look at the coin trends over time

df3 = df.groupby('name', sort=False)[['quote.USD.percent_change_1h','quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d']].mean()
df3
# Out:
#               quote.USD.percent_change_1h  quote.USD.percent_change_24h  \
# name
# Bitcoin                          -0.09851                      -1.38761
# Ethereum                          0.27587                      -3.97019
# Tether USDt                       0.00405                      -0.03127
# XRP                               0.60389                       4.17565
# BNB                               0.36004                      -2.25981
# USDC                              0.00262                      -0.01501
# Solana                           -0.00113                      -0.29969
# TRON                              0.06559                      -1.00342
# Dogecoin                          0.71619                       5.28756
# Bitcoin Cash                      0.44980                      -0.92506
# Cardano                           0.67287                       0.12334
# Hyperliquid                       0.38894                      -1.56202
# UNUS SED LEO                      0.06321                      -2.74576
# Ethena USDe                      -0.00286                      -0.02414
# Chainlink                         0.44896                      -1.85352
#
#               quote.USD.percent_change_7d  quote.USD.percent_change_30d  \
# name
# Bitcoin                          -2.90392                     -27.37007
# Ethereum                         -4.81928                     -39.06587
# Tether USDt                       0.02173                      -0.00520
# XRP                               5.91752                     -25.26345
# BNB                              -3.67946                     -33.16152
# USDC                              0.02268                       0.04077
# Solana                           -1.24780                     -38.76477
# TRON                              0.68352                      -8.54392
# Dogecoin                         10.80563                     -21.01945
# Bitcoin Cash                      4.39067                      -6.96505
# Cardano                           4.59236                     -26.28711
# Hyperliquid                      -1.51307                      23.63603
# UNUS SED LEO                      2.11887                      -5.30386
# Ethena USDe                       0.03938                      -0.09108
# Chainlink                        -0.56414                     -35.11230
#
#               quote.USD.percent_change_60d  quote.USD.percent_change_90d
# name
# Bitcoin                          -23.18032                     -26.72502
# Ethereum                         -33.32424                     -35.68593
# Tether USDt                       -0.03731                       0.02270
# XRP                              -22.20372                     -31.15807
# BNB                              -28.76293                     -32.05534
# USDC                              -0.00644                       0.01079
# Solana                           -34.09570                     -36.76416
# TRON                              -0.33698                      -4.72719
# Dogecoin                         -19.88124                     -32.41403
# Bitcoin Cash                      -1.06165                       9.76343
# Cardano                          -28.03616                     -40.56657
# Hyperliquid                       12.26194                     -18.26840
# UNUS SED LEO                      19.24242                      -7.96975
# Ethena USDe                       -0.02042                       0.04479
# Chainlink                        -31.99068                     -35.66967

# %%
df4 = df3.stack()
df4
# Out:
# name
# Bitcoin    quote.USD.percent_change_1h     -0.09851
#            quote.USD.percent_change_24h    -1.38761
#            quote.USD.percent_change_7d     -2.90392
#            quote.USD.percent_change_30d   -27.37007
#            quote.USD.percent_change_60d   -23.18032
#                                              ...
# Chainlink  quote.USD.percent_change_24h    -1.85352
#            quote.USD.percent_change_7d     -0.56414
#            quote.USD.percent_change_30d   -35.11230
#            quote.USD.percent_change_60d   -31.99068
#            quote.USD.percent_change_90d   -35.66967
# Length: 90, dtype: float64

# %%
type(df4)
# Out:
# pandas.Series

# %%
df5 = df4.to_frame(name='values')
df5
# Out:
#                                           values
# name
# Bitcoin   quote.USD.percent_change_1h   -0.09851
#           quote.USD.percent_change_24h  -1.38761
#           quote.USD.percent_change_7d   -2.90392
#           quote.USD.percent_change_30d -27.37007
#           quote.USD.percent_change_60d -23.18032
# ...                                          ...
# Chainlink quote.USD.percent_change_24h  -1.85352
#           quote.USD.percent_change_7d   -0.56414
#           quote.USD.percent_change_30d -35.11230
#           quote.USD.percent_change_60d -31.99068
#           quote.USD.percent_change_90d -35.66967
#
# [90 rows x 1 columns]

# %%
 df5.count()
# Out:
# values    90
# dtype: int64

# %%
n = len(df5)          # albo df5.shape[0]
pd.Index(range(n))
df6 = df5.reset_index()
df6
# Out:
#          name                       level_1    values
# 0     Bitcoin   quote.USD.percent_change_1h  -0.09851
# 1     Bitcoin  quote.USD.percent_change_24h  -1.38761
# 2     Bitcoin   quote.USD.percent_change_7d  -2.90392
# 3     Bitcoin  quote.USD.percent_change_30d -27.37007
# 4     Bitcoin  quote.USD.percent_change_60d -23.18032
# ..        ...                           ...       ...
# 85  Chainlink  quote.USD.percent_change_24h  -1.85352
# 86  Chainlink   quote.USD.percent_change_7d  -0.56414
# 87  Chainlink  quote.USD.percent_change_30d -35.11230
# 88  Chainlink  quote.USD.percent_change_60d -31.99068
# 89  Chainlink  quote.USD.percent_change_90d -35.66967
#
# [90 rows x 3 columns]

# %%
df7 = df6.rename(columns={'level_1': 'percent_change'})
df7
# Out:
#          name                percent_change    values
# 0     Bitcoin   quote.USD.percent_change_1h  -0.09851
# 1     Bitcoin  quote.USD.percent_change_24h  -1.38761
# 2     Bitcoin   quote.USD.percent_change_7d  -2.90392
# 3     Bitcoin  quote.USD.percent_change_30d -27.37007
# 4     Bitcoin  quote.USD.percent_change_60d -23.18032
# ..        ...                           ...       ...
# 85  Chainlink  quote.USD.percent_change_24h  -1.85352
# 86  Chainlink   quote.USD.percent_change_7d  -0.56414
# 87  Chainlink  quote.USD.percent_change_30d -35.11230
# 88  Chainlink  quote.USD.percent_change_60d -31.99068
# 89  Chainlink  quote.USD.percent_change_90d -35.66967
#
# [90 rows x 3 columns]

# %%
df7['percent_change'] = df7['percent_change'].replace(['quote.USD.percent_change_1h','quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d'],['1h','24h','7d','30d','60d','90d'])
df7
# Out:
#          name percent_change    values
# 0     Bitcoin             1h  -0.09851
# 1     Bitcoin            24h  -1.38761
# 2     Bitcoin             7d  -2.90392
# 3     Bitcoin            30d -27.37007
# 4     Bitcoin            60d -23.18032
# ..        ...            ...       ...
# 85  Chainlink            24h  -1.85352
# 86  Chainlink             7d  -0.56414
# 87  Chainlink            30d -35.11230
# 88  Chainlink            60d -31.99068
# 89  Chainlink            90d -35.66967
#
# [90 rows x 3 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.catplot(x='percent_change', y='values',hue='name', data=df7, kind='point')

# %%
df10 = df[['name','quote.USD.price','timestamp']]
df10 = df10.query("name == 'Bitcoin'")
df10
# Out:
#        name  quote.USD.price                   timestamp
# 0   Bitcoin      68963.70266  2026-02-15 16:26:04.766852
# 15  Bitcoin      68925.04231  2026-02-15 16:27:05.135207
# 30  Bitcoin      68965.68588  2026-02-15 16:28:05.507406

# %%
sns.set_theme(style="darkgrid")
sns.lineplot(x='timestamp', y='quote.USD.price', data=df10)
# Out:
# <Axes: xlabel='timestamp', ylabel='quote.USD.price'>
