# %% [markdown]
# # API — Application Programming Interface
#
# An **API (Application Programming Interface)** is a set of rules and protocols that allows different software applications to communicate with each other.
#
# An API acts as a **messenger** between systems. It receives a request from one system, sends it to another, and then returns the response.
#
# ---
#
# ## Simple Explanation
#
# Imagine you are using a weather app:
#
# 1. You open the app and request today’s weather.
# 2. The app sends a request to a remote server.
# 3. The server processes the request.
# 4. The server sends the weather data back.
# 5. The app displays the result.
#
# The **API** makes this communication possible.
#
# ---
#
# ## Technical Definition
#
# An API defines how software components interact by specifying:
#
# - **Endpoints** — URLs where requests are sent
# - **Methods** — such as:
#   - `GET` (retrieve data)
#   - `POST` (create data)
#   - `PUT` (update data)
#   - `DELETE` (remove data)
# - **Request format** — how data is sent
# - **Response format** — how data is returned
#
# ---
#
# ## Common API Types
#
# ### REST API
# - Uses HTTP methods
# - Typically returns JSON
# - Widely used in web applications
#
# ### GraphQL
# - Allows clients to request specific data
# - Flexible and efficient
#
# ### SOAP
# - XML-based protocol
# - More strict and structured
# - Often used in enterprise systems
#
# ---
#
# ## Real-World Examples
#
# - Payment processing APIs
# - Login with Google
# - Fetching social media posts
# - Booking flights online
#
# ---
#
# ## Summary
#
# An API is a structured way for different software systems to communicate securely and efficiently.

# %%
#script from
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'15',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': 'af493535117b4ed58d62a05fc30aa941',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2026-02-15T15:26:04.979Z', 'error_code': 0, 'error_message': None, 'elapsed': 31, 'credit_count': 1, 'notice': None, 'total_count': 8835}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 12561, 'date_added': '2010-07-13T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'bitcoin-ecosystem', 'layer-1', 'ftx-bankruptcy-estate', '2017-2018-alt-season', 'us-strategic-crypto-reserve', 'binance-ecosystem', 'binance-listing'], 'max_supply': 21000000, 'circulating_supply': 19989828, 'total_supply': 19989828, 'infinite_supply': False, 'minted_market_cap': 1378572554495.69, 'platform': None, 'cmc_rank': 1, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2026-02-15T15:24:00.000Z', 'quote': {'USD': {'price': 68963.7026639592, 'volume_24h': 36465267209.13564, 'volume_change_24h': -7.7959, 'percent_change_1h': -0.07116606, 'percent_change_24h': -1.26493096, 'percent_change_7d': -3.06272604, 'percent_change_30d': -27.38530701, 'percent_change_60d': -23.23646849, 'percent_change_90d': -26.70861105, 'market_cap': 1378572554495.686, 'market_cap_dominance': 58.2266, 'fully_diluted_market_cap': 1448237755943.14, 'tvl': None, 'last_updated': '2026-02-15T15:24:00.000Z'}}}, {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum', 'num_market_pairs': 11567, 'date_added': '2015-08-07T00:00:00.000Z', 'tags': ['pos', 'smart-contracts', 'ethereum-ecosystem', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'hashkey-capital-portfolio', 'kenetic-capital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'ethereum-pow-ecosystem', 'layer-1', 'ftx-bankruptcy-estate', 'sora-ecosystem', 'rsk-rbtc-ecosystem', 'world-liberty-financial-portfolio', 'us-strategic-crypto-reserve', 'binance-ecosystem', 'binance-listing', 'abstract-chain-ecosystem', 'unichain-ecosystem', 'soneium-ecosystem', 'sophon-ecosystem'], 'max_supply': None, 'circulating_supply': 120692457.89999667, 'total_supply': 120692457.89999667, 'infinite_supply': True, 'minted_market_cap': 242319683452.66, 'platform': None, 'cmc_rank': 2, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2026-02-15T15:24:00.000Z', 'quote': {'USD': {'price': 2007.7450378335946, 'volume_24h': 25048268084.261387, 'volume_change_24h': 34.5077, 'percent_change_1h': 0.30476215, 'percent_change_24h': -3.90737839, 'percent_change_7d': -5.16346899, 'percent_change_30d': -39.08794393, 'percent_change_60d': -33.40841448, 'percent_change_90d': -35.70988184, 'market_cap': 242319683452.65833, 'market_cap_dominance': 10.2348, 'fully_diluted_market_cap': 242319683452.66, 'tvl': None, 'last_updated': '2026-02-15T15:24:00.000Z'}}}, {'id': 825, 'name': 'Tether USD ...

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
#showing the data in a table format
df = pd.json_normalize(data["data"])
df['timestamp'] = pd.to_datetime('now')
df
# Out:
#        id          name symbol          slug  num_market_pairs  \
# 0       1       Bitcoin    BTC       bitcoin             12561
# 1    1027      Ethereum    ETH      ethereum             11567
# 2     825   Tether USDt   USDT        tether            171236
# 3      52           XRP    XRP           xrp              1798
# 4    1839           BNB    BNB           bnb              3134
# 5    3408          USDC   USDC      usd-coin             37475
# 6    5426        Solana    SOL        solana              1089
# 7    1958          TRON    TRX          tron              1299
# 8      74      Dogecoin   DOGE      dogecoin              1401
# 9    1831  Bitcoin Cash    BCH  bitcoin-cash              1137
# 10   2010       Cardano    ADA       cardano              1681
# 11  32196   Hyperliquid   HYPE   hyperliquid               238
# 12   3957  UNUS SED LEO    LEO  unus-sed-leo                67
# 13  29470   Ethena USDe   USDe   ethena-usde               295
# 14   1975     Chainlink   LINK     chainlink              2212
#
#                   date_added  \
# 0   2010-07-13T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2013-08-04T00:00:00.000Z
# 4   2017-07-25T00:00:00.000Z
# 5   2018-10-08T00:00:00.000Z
# 6   2020-04-10T00:00:00.000Z
# 7   2017-09-13T00:00:00.000Z
# 8   2013-12-15T00:00:00.000Z
# 9   2017-07-23T00:00:00.000Z
# 10  2017-10-01T00:00:00.000Z
# 11  2024-07-15T10:14:50.000Z
# 12  2019-05-21T00:00:00.000Z
# 13  2024-02-20T11:05:01.000Z
# 14  2017-09-20T00:00:00.000Z
#
#                                                  tags    max_supply  \
# 0   [mineable, pow, sha-256, store-of-value, state...  2.100000e+07
# 1   [pos, smart-contracts, ethereum-ecosystem, coi...           NaN
# 2   [stablecoin, asset-backed-stablecoin, usd-stab...           NaN
# 3   [medium-of-exchange, enterprise-solutions, xrp...  1.000000e+11
# 4   [marketplace, centralized-exchange, payments, ...  1.363593e+08
# 5   [medium-of-exchange, stablecoin, asset-backed-...           NaN
# 6   [pos, platform, solana-ecosystem, cms-holdings...           NaN
# 7   [media, payments, tron-ecosystem, layer-1, dwf...           NaN
# 8   [mineable, pow, scrypt, medium-of-exchange, me...           NaN
# 9   [mineable, pow, sha-256, marketplace, medium-o...  2.100000e+07
# 10  [dpos, pos, platform, research, smart-contract...  4.500000e+10
# 11  [decentralized-exchange-dex-token, defi, deriv...  9.616715e+08
# 12  [marketplace, centralized-exchange, discount-t...           NaN
# 13  [stablecoin, asset-backed-stablecoin, binance-...           NaN
# 14  [platform, cosmos-ecosystem, defi, privacy, in...  1.000000e+09
#
#     circulating_supply  total_supply  infinite_supply  minted_market_cap  \
# 0         1.998983e+07  1.998983e+07            False       1.378573e+12
# 1         1.206925e+08  1.206925e+08             True       2.423197e+11
# 2         1.837553e+11  1.879648e+11             True       1.878603e+11
# 3         6.091732e+10  9.998572e+10            False       1.531167e+11
# 4         1.363593e+08  1.363593e+08            False       8.468468e+10
# 5         7.357899e+10  7.357899e+10            False       7.358325e+10
# 6         5.679576e+08  6.203911e+08             True       5.411367e+10
# 7         9.472470e+10  9.472470e+10             True       2.657415e+10
# 8         1.687518e+11  1.687518e+11             True       1.828167e+10
# 9         1.999516e+07  1.999516e+07            False       1.114749e+10
# 10        3.606615e+10  4.499454e+10            False       1.283713e+10
# 11        2.592810e+08  9.583919e+08            False       2.961682e+10
# 12        9.213530e+08  9.852395e+08            False       8.309555e+09
# 13        6.304779e+09  6.304779e+09             True       6.298056e+09
# 14        7.081000e+08  1.000000e+09            False       8.862643e+09
#
#     platform  cmc_rank  self_reported_circulating_supply  \
# 0        NaN         1                               NaN
# 1        NaN         2                               NaN
# 2        NaN         3                               NaN
# 3        NaN         4                               NaN
# 4        NaN         5                               NaN
# 5        NaN         6                      6.090122e+10
# 6        NaN         7                      5.252369e+08
# 7        NaN         8                      9.466789e+10
# 8        NaN         9                               NaN
# 9        NaN        10                               NaN
# 10       NaN        11                      3.799790e+10
# 11       NaN        12                      3.339317e+08
# 12       NaN        13                               NaN
# 13       NaN        14                               NaN
# 14       NaN        15                               NaN
#
#     self_reported_market_cap tvl_ratio              last_updated  \
# 0                        NaN      None  2026-02-15T15:24:00.000Z
# 1                        NaN      None  2026-02-15T15:24:00.000Z
# 2                        NaN      None  2026-02-15T15:24:00.000Z
# 3                        NaN      None  2026-02-15T15:25:00.000Z
# 4                        NaN      None  2026-02-15T15:25:00.000Z
# 5               6.090475e+10      None  2026-02-15T15:24:00.000Z
# 6               4.581384e+10      None  2026-02-15T15:24:00.000Z
# 7               2.655821e+10      None  2026-02-15T15:25:00.000Z
# 8                        NaN      None  2026-02-15T15:25:00.000Z
# 9                        NaN      None  2026-02-15T15:24:00.000Z
# 10              1.084096e+10      None  2026-02-15T15:25:00.000Z
# 11              1.031937e+10      None  2026-02-15T15:25:00.000Z
# 12                       NaN      None  2026-02-15T15:25:00.000Z
# 13                       NaN      None  2026-02-15T15:25:00.000Z
# 14                       NaN      None  2026-02-15T15:25:00.000Z
#
#     quote.USD.price  quote.USD.volume_24h  quote.USD.volume_change_24h  \
# 0      68963.702664          3.646527e+10                      -7.7959
# 1       2007.745038          2.504827e+10                      34.5077
# 2          0.999444          8.537938e+10                       9.8877
# 3          1.531385          5.655892e+09                     114.5216
# 4        621.040826          1.469150e+09                     -10.9604
# 5          1.000058          8.144007e+09                     -13.7117
# 6         87.225092          3.966498e+09                      19.5433
# 7          0.280541          4.531076e+08                     -17.3787
# 8          0.108335          2.985698e+09                     197.4198
# 9        557.509325          3.172714e+08                     -44.1053
# 10         0.285304          7.067928e+08                      62.2530
# 11        30.902621          2.169432e+08                     -10.5330
# 12         8.434046          1.043143e+06                      63.7251
# 13         0.998934          6.389515e+07                     -16.5649
# 14         8.862643          6.542058e+08                       5.7878
#
#     quote.USD.percent_change_1h  quote.USD.percent_change_24h  \
# 0                     -0.071166                     -1.264931
# 1                      0.304762                     -3.907378
# 2                     -0.002770                     -0.043022
# 3                      0.605206                      4.189284
# 4                      0.360665                     -2.258171
# 5                      0.005929                     -0.012135
# 6                      0.036572                     -0.275214
# 7                      0.057493                     -1.011091
# 8                      0.710657                      5.297373
# 9                      0.443423                     -0.916157
# 10                     0.688311                      0.125203
# 11                     0.389746                     -1.575501
# 12                     0.090379                     -2.744834
# 13                    -0.003574                     -0.023288
# 14                     0.456129                     -1.840349
#
#     quote.USD.percent_change_7d  quote.USD.percent_change_30d  \
# 0                     -3.062726                    -27.385307
# 1                     -5.163469                    -39.087944
# 2                      0.019606                     -0.008208
# 3                      5.774884                    -25.305315
# 4                     -3.748084                    -33.171961
# 5                      0.024809                      0.066948
# 6                     -1.322075                    -38.780246
# 7                      0.663586                     -8.563585
# 8                     10.759118                    -21.026421
# 9                      4.392190                     -6.957225
# 10                     4.447470                    -26.326710
# 11                    -1.630016                     23.546731
# 12                     2.130725                     -5.315149
# 13                     0.039510                     -0.089474
# 14                    -0.688225                    -35.144346
#
#     quote.USD.percent_change_60d  quote.USD.percent_change_90d  \
# 0                     -23.236468                    -26.708611
# 1                     -33.408414                    -35.709882
# 2                      -0.070778                      0.005839
# 3                     -22.236700                    -31.171631
# 4                     -28.798890                    -32.046587
# 5                      -0.021743                      0.007190
# 6                     -34.115237                    -36.778049
# 7                      -0.347565                     -4.711318
# 8                     -19.890374                    -32.423982
# 9                      -1.052804                      9.792979
# 10                    -28.099867                    -40.595132
# 11                     12.133387                    -18.323668
# 12                     19.056570                     -7.977823
# 13                     -0.021636                      0.039571
# 14                    -32.063739                    -35.692373
#
#     quote.USD.market_cap  quote.USD.market_cap_dominance  \
# 0           1.378573e+12                         58.2266
# 1           2.423197e+11                         10.2348
# 2           1.836531e+11                          7.7569
# 3           9.328788e+10                          3.9402
# 4           8.468468e+10                          3.5768
# 5           7.358325e+10                          3.1079
# 6           4.954015e+10                          2.0924
# 7           2.657415e+10                          1.1224
# 8           1.828167e+10                          0.7722
# 9           1.114749e+10                          0.4708
# 10          1.028982e+10                          0.4346
# 11          8.012462e+09                          0.3384
# 12          7.770734e+09                          0.3282
# 13          6.298056e+09                          0.2660
# 14          6.275637e+09                          0.2651
#
#     quote.USD.fully_diluted_market_cap quote.USD.tvl  \
# 0                         1.448238e+12          None
# 1                         2.423197e+11          None
# 2                         1.878603e+11          None
# 3                         1.531385e+11          None
# 4                         8.468468e+10          None
# 5                         7.358325e+10          None
# 6                         5.411367e+10          None
# 7                         2.657415e+10          None
# 8                         1.828167e+10          None
# 9                         1.170770e+10          None
# 10                        1.283869e+10          None
# 11                        2.971817e+10          None
# 12                        8.309555e+09          None
# 13                        6.298056e+09          None
# 14                        8.862643e+09          None
#
#       quote.USD.last_updated  platform.id platform.name platform.symbol  \
# 0   2026-02-15T15:24:00.000Z          NaN           NaN             NaN
# 1   2026-02-15T15:24:00.000Z          NaN           NaN             NaN
# 2   2026-02-15T15:24:00.000Z       1027.0      Ethereum             ETH
# 3   2026-02-15T15:25:00.000Z          NaN           NaN             NaN
# 4   2026-02-15T15:25:00.000Z          NaN           NaN             NaN
# 5   2026-02-15T15:24:00.000Z       1027.0      Ethereum             ETH
# 6   2026-02-15T15:24:00.000Z          NaN           NaN             NaN
# 7   2026-02-15T15:25:00.000Z          NaN           NaN             NaN
# 8   2026-02-15T15:25:00.000Z          NaN           NaN             NaN
# 9   2026-02-15T15:24:00.000Z          NaN           NaN             NaN
# 10  2026-02-15T15:25:00.000Z          NaN           NaN             NaN
# 11  2026-02-15T15:25:00.000Z      32196.0   Hyperliquid            HYPE
# 12  2026-02-15T15:25:00.000Z       1027.0      Ethereum             ETH
# 13  2026-02-15T15:25:00.000Z       1027.0      Ethereum             ETH
# 14  2026-02-15T15:25:00.000Z       1027.0      Ethereum             ETH
#
#    platform.slug                      platform.token_address  \
# 0            NaN                                         NaN
# 1            NaN                                         NaN
# 2       ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3            NaN                                         NaN
# 4            NaN                                         NaN
# 5       ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 6            NaN                                         NaN
# 7            NaN                                         NaN
# 8            NaN                                         NaN
# 9            NaN                                         NaN
# 10           NaN                                         NaN
# 11   hyperliquid          0x0d01dc56dcaaca66ad901c959b4011ec
# 12      ethereum  0x2af5d2ad76741191d15dfe7bf6ac92d4bd912ca3
# 13      ethereum  0x4c9edd5852cd905f086c759e8383e09bff1e68b3
# 14      ethereum  0x514910771af9ca656af840dff83e8264ecf986ca
#
#                     timestamp
# 0  2026-02-15 16:26:04.392044
# 1  2026-02-15 16:26:04.392044
# 2  2026-02-15 16:26:04.392044
# 3  2026-02-15 16:26:04.392044
# 4  2026-02-15 16:26:04.392044
# 5  2026-02-15 16:26:04.392044
# 6  2026-02-15 16:26:04.392044
# 7  2026-02-15 16:26:04.392044
# 8  2026-02-15 16:26:04.392044
# 9  2026-02-15 16:26:04.392044
# 10 2026-02-15 16:26:04.392044
# 11 2026-02-15 16:26:04.392044
# 12 2026-02-15 16:26:04.392044
# 13 2026-02-15 16:26:04.392044
# 14 2026-02-15 16:26:04.392044

# %%
def api_runner():
    global df
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
    #Original Sandbox Environment: 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
    parameters = {
      'start':'1',
      'limit':'15',
      'convert':'USD'
    }
    headers = {
      'Accepts': 'application/json',
      'X-CMC_PRO_API_KEY': '0ad53085-1cb2-4eb8-ad9e-3ffbd7e56509',
    }

    session = Session()
    session.headers.update(headers)

    try:
      response = session.get(url, params=parameters)
      data = json.loads(response.text)
      #print(data)
    except (ConnectionError, Timeout, TooManyRedirects) as e:
      print(e)

      # Use this if you want to create a csv and append data to it
    df = pd.json_normalize(data['data'])
    df['timestamp'] = pd.to_datetime('now')
    df

    if not os.path.isfile(r'C:\dysk\CV — kopia\Naukaa\Python\Projects\API_Crypto_Project\Api_data\crypto_data.csv'):
        df.to_csv(r'C:\dysk\CV — kopia\Naukaa\Python\Projects\API_Crypto_Project\Api_data\crypto_data.csv', header='column_names')
    else:
        df.to_csv(r'C:\dysk\CV — kopia\Naukaa\Python\Projects\API_Crypto_Project\Api_data\crypto_data.csv', mode='a', header=False)

# %%
import os
from time import time
from time import sleep
for i in range (333):
    api_runner()
    print('Api Runner completed')
    sleep(60)
exit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 5
#       3 from time import sleep
#       4 for i in range (333):
# ----> 5     api_runner()
#       6     print('Api Runner completed')
#       7     sleep(60)
#
# NameError: name 'api_runner' is not defined
