# %%
import pandas as pd

# %%
#df = pd.read_csv(r'C:\dysk\CV — kopia\Naukaa\Python\Data\csv_files\layoffs.csv')
#df
df = pd.read_table(r'C:\dysk\CV — kopia\Naukaa\Python\Data\csv_files\layoffs.csv', sep=',')
df
# Out:
#                company       location     industry  total_laid_off  \
# 0            Atlassian         Sydney        Other           500.0
# 1             SiriusXM  New York City        Media           475.0
# 2               Alerzo         Ibadan       Retail           400.0
# 3               UpGrad         Mumbai    Education           120.0
# 4                 Loft      Sao Paulo  Real Estate           340.0
# ...                ...            ...          ...             ...
# 2356         Blackbaud     Charleston        Other           500.0
# 2357             Yahoo    SF Bay Area     Consumer          1600.0
# 2358             Hibob       Tel Aviv           HR            70.0
# 2359            Casper  New York City       Retail             NaN
# 2360  Wildlife Studios      Sao Paulo     Consumer           300.0
#
#       percentage_laid_off        date     stage        country  \
# 0                    0.05    3/6/2023  Post-IPO      Australia
# ...

# %% [markdown]
# Jesli chcemt konkretny sheet w excel

# %%
df2 = pd.read_excel(r'C:\dysk\CV — kopia\Naukaa\PowerBI\data\01_Apocolypse Food Prep.xlsx', sheet_name='Sheet1')
df2
# Out:
#       Store            Product  Price       Date
# 0   Walmart               Rice  25.00 2022-01-01
# 1    Costco               Rice  23.00 2022-01-01
# 2    Target               Rice  22.99 2022-01-01
# 3   Walmart               Rice  25.75 2022-02-01
# 4    Costco               Rice  23.99 2022-02-01
# 5    Target               Rice  23.25 2022-02-01
# 6   Walmart               Rice  26.99 2022-03-01
# 7    Costco               Rice  24.99 2022-03-01
# 8    Target               Rice  24.25 2022-03-01
# 9   Walmart               Rice  26.99 2022-04-01
# 10   Costco               Rice  25.25 2022-04-01
# 11   Target               Rice  24.75 2022-04-01
# 12  Walmart        Dried Beans  22.99 2022-01-01
# 13   Costco        Dried Beans  20.99 2022-01-01
# 14   Target        Dried Beans  23.99 2022-01-01
# 15  Walmart        Dried Beans  23.99 2022-02-01
# 16   Costco        Dried Beans  22.99 2022-02-01
# 17   Target        Dried Beans  24.99 2022-02-01
# ...

# %%
df2.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Store    60 non-null     str
#  1   Product  60 non-null     str
#  2   Price    60 non-null     float64
#  3   Date     60 non-null     datetime64[us]
# dtypes: datetime64[us](1), float64(1), str(2)
# memory usage: 2.0 KB
