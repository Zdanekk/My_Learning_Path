# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# 1st Lesson Variables

# %%
x=22
print(x)
# Out:
# 22

# %%
type(x)
# Out:
# int

# %%
y= 'Mint Chocolate Chip'
print(y)
# Out:
# Mint Chocolate Chip

# %%
type (y)
# Out:
# str

# %%
x,y,z="Chocolate","Vanilla","Strawberry"
print(x)
print(y)
print(z)
# Out:
# Chocolate
# Vanilla
# Strawberry

# %%
x = y = z = "clear"
print(x)
print(y)
print(z)
# Out:
# clear
# clear
# clear

# %%
ice_cream=["Chocolate","Vanilla","Strawberry"]
x,y,z=ice_cream
print(x)
print(y)
print(z)
# Out:
# Chocolate
# Vanilla
# Strawberry

# %%
#camel case
testVariableName = "value"

# %%
#Pascal Case
TestVariableName = "value"

# %%
#Snake Case
#Test_Variable_Name = "value"
test_variable_name = "value"

# %% [markdown]
# nie mozesz dodawac stringa z intem
# ex. x= "Ice Cream"
# y=2
# print(x+y)

# %%
#teraz dziala poprawnie
x= "Ice Cream"
y=2
print(x,y)
# Out:
# Ice Cream 2
