# %% [markdown]
# If_Elif_Else Statements

# %%
if 25>10 :
    print("25 is greater than 10")
# Out:
# 25 is greater than 10

# %%
if 25<10 :
    print("25 is less than 10")
elif 25<30 :
    print("25 is less than 30 but greater than 10")
else :
    print("25 is greater than 30")
# Out:
# 25 is less than 30 but greater than 10

# %% [markdown]
# mozna nielimitowana ilosc elifow
